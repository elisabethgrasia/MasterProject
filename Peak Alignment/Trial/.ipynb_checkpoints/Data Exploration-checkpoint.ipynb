# %% [markdown]
# It is mentioned in the paper that they are using the ambient air samples from P. falciparum CHMI trial and the healthy control human breath samples to generate training and validation data. Selected masses are m/z = 103, 115, and 143 Da with RTs between 14-15 min from the air samples for training.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ###### P. Falciparum ambient air - data exploration

# %%
pf = pd.read_csv('pfambient_csv.csv')
pf.head()
# Out:
#      nan        35        36    37   38        39        40        41  \
# 0  0.014   0.00000  35.28571   0.0  0.0  10.01136   0.00000  10.56250
# 1  0.017   0.00000  12.08654  16.0  0.0  11.24039   0.00000  11.68056
# 2  0.020   0.00000  25.57143   0.0  0.0   0.00000  37.47615   0.00000
# 3  0.024   0.00000  10.00000   0.0  0.0  12.03125  15.34722   0.00000
# 4  0.027  11.01136  14.12500   0.0  0.0   0.00000   0.00000   0.00000
#
#          42       43  ...  342       343       344  345  346  347      348  \
# 0   0.00000  28.8103  ...  0.0   0.00000   0.00000  0.0  0.0  0.0   0.0000
# 1   0.00000  11.2500  ...  0.0  15.16447  10.24039  0.0  0.0  0.0   0.0000
# 2   0.00000   0.0000  ...  0.0   0.00000   0.00000  0.0  0.0  0.0   0.0000
# 3   0.00000   0.0000  ...  0.0   0.00000  10.20000  0.0  0.0  0.0  14.5329
# 4  17.09091   0.0000  ...  0.0   0.00000   0.00000  0.0  0.0  0.0   0.0000
#
#    349  350  Unnamed: 317
# 0  0.0  0.0           NaN
# 1  0.0  0.0           NaN
# ...

# %%
pf.describe()
# Out:
#                 nan            35            36            37            38  \
# count  14898.000000  14898.000000  14898.000000  14898.000000  14898.000000
# mean      25.004446    288.059676    575.671055    632.920655    680.484625
# std       14.429842    890.307836   1738.702030   1745.628064   1773.317209
# min        0.014000      0.000000      0.000000      0.000000      0.000000
# 25%       12.509000     97.740612    208.756025    222.851825    231.115925
# 50%       25.004500    156.579950    316.857100    349.101850    372.339400
# 75%       37.500000    238.133350    463.036000    525.743900    572.890700
# max       49.995000  14391.860000  25768.030000  25329.620000  26922.140000
#
#                   39             40            41             42  \
# count   14898.000000   14898.000000  1.489800e+04   14898.000000
# mean     5387.477741    1593.004228  3.385424e+04    7040.351533
# std     14702.402371    4296.646624  1.443684e+05   20751.101304
# ...

# %%
pf.size
# Out:
# 4737564

# %%
pf.shape
# Out:
# (14898, 318)

# %%
pf.isnull()
# Out:
#          nan     35     36     37     38     39     40     41     42     43  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 14893  False  False  False  False  False  False  False  False  False  False
# 14894  False  False  False  False  False  False  False  False  False  False
# 14895  False  False  False  False  False  False  False  False  False  False
# 14896  False  False  False  False  False  False  False  False  False  False
# 14897  False  False  False  False  False  False  False  False  False  False
#
# ...

# %% [markdown]
# The given dataset has been well-analyzed about how many peaks each has.
